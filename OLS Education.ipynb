# %%
import pandas as pd
Education = pd. read_csv('Education.csv')
Education
# Out:
#     Unnamed: 0                State1  Highschoold  Bachelord  Hillary   Donald
# 0            1                Alaska         64.1       27.5   116454   163387
# 1            2               Arizona         58.8       26.9  1161167  1252401
# 2            3              Arkansas         63.6       20.1   380494   684872
# 3            4            California         50.5       30.7  8753788  4483810
# 4            5              Colorado         53.2       37.0  1338870  1202484
# 5            6           Connecticut         52.7       36.5   897572   673215
# 6            7              Delaware         58.8       28.9   235603   185127
# 7            8  District Of Columbia         36.0       52.4   282830    12723
# 8            9               Florida         59.7       26.4  4504975  4617886
# 9           10               Georgia         56.7       28.0  1877963  2089104
# 10          11                Hawaii         60.3       30.1   266891   128847
# ...

# %%
import statsmodels.api as sm

Y = Education['Hillary']
X = Education[['Highschoold', 'Bachelord']]
model = sm.OLS(Y,X).fit()

print (model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Hillary   R-squared:                       0.426
# Model:                            OLS   Adj. R-squared:                  0.402
# Method:                 Least Squares   F-statistic:                     17.78
# Date:                Mon, 30 Apr 2018   Prob (F-statistic):           1.67e-06
# Time:                        14:03:04   Log-Likelihood:                -783.06
# No. Observations:                  50   AIC:                             1570.
# Df Residuals:                      48   BIC:                             1574.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Highschoold -4266.3848   1.34e+04     -0.318      0.752   -3.13e+04    2.27e+04
# ...

# %%
import statsmodels.api as sm

Y = Education['Donald']
X = Education[['Highschoold', 'Bachelord']]
model = sm.OLS(Y,X).fit()

print (model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Donald   R-squared:                       0.522
# Model:                            OLS   Adj. R-squared:                  0.502
# Method:                 Least Squares   F-statistic:                     26.16
# Date:                Mon, 30 Apr 2018   Prob (F-statistic):           2.07e-08
# Time:                        14:03:38   Log-Likelihood:                -769.27
# No. Observations:                  50   AIC:                             1543.
# Df Residuals:                      48   BIC:                             1546.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Highschoold  1.384e+04   1.02e+04      1.358      0.181   -6648.786    3.43e+04
# ...
